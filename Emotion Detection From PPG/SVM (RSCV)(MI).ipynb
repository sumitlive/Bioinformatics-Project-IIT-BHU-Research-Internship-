# %%
import pandas as pd
import numpy as np

X_resampled = np.load("X_resampled.npy")
y_resampled = np.load("y_resampled.npy")
groups_resampled = np.load("groups_resampled.npy")
df_features = pd.read_csv("Features_130.csv", index_col=0)

# %%
import numpy as np
from collections import Counter
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedGroupKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.metrics import accuracy_score, confusion_matrix
from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
from scipy.stats import uniform, randint

# Cross-validation setup
sgkf = StratifiedGroupKFold(n_splits=2, shuffle=True, random_state=206)  # Use n_splits=5 for optimal value

# Initialize variables
fold_accuracies = []
all_test = []
all_pred = []
feature_score_sums = {}
feature_counts = {}

# Splitting according to CV strategy
for fold_idx, (train_idx, test_idx) in tqdm(enumerate(sgkf.split(X_resampled, y_resampled, groups_resampled))):
    print(f"\n=== Fold {fold_idx + 1} ===")
    start_time = time.time()

    # Split into train and test data
    X_train, y_train = X_resampled[train_idx], y_resampled[train_idx]
    X_test, y_test = X_resampled[test_idx], y_resampled[test_idx]

    # List to store accuracy for each number of features
    accuracies = []
    
    max_features = min(130, X_train.shape[1])
        
    for k in range(1, max_features + 1):
        # Define the pipeline with SVM
        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('feature_selector', SelectKBest(score_func=mutual_info_classif, k=k)),
            ('classifier', SVC(random_state=42))
        ])

        # Define hyperparameter distributions for SVM
        param_distributions = {
            'classifier__C': uniform(0.1, 10),  # C values from 0.1 to 10.1
            'classifier__kernel': ['linear', 'rbf', 'poly'],
            'classifier__gamma': ['scale', 'auto'] + list(np.logspace(-3, 3, 7)),  # Gamma values
            'classifier__degree': randint(2, 5)  # Degree for polynomial kernel
        }

        # Set up RandomizedSearchCV
        random_search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_distributions,
            n_iter=1,  # Adjust as needed, e.g., 10 for better tuning
            cv=3,
            scoring='accuracy',
            n_jobs=-1,
            random_state=42
        )

        # Fit RandomizedSearchCV
        random_search.fit(X_train, y_train)

        # Get the best pipeline
        best_pipeline = random_search.best_estimator_

        # Get the feature selector
        feature_selector = best_pipeline.named_steps['feature_selector']

        # Get the mutual information scores
        mi_scores = feature_selector.scores_

        # Get the selected feature indices
        selected_features = feature_selector.get_support(indices=True)

        # Get the mi_scores for selected features
        selected_mi_scores = mi_scores[selected_features]

        # Update cumulative scores and counts
        for idx, score in zip(selected_features, selected_mi_scores):
            feature_score_sums[idx] = feature_score_sums.get(idx, 0) + score
            feature_counts[idx] = feature_counts.get(idx, 0) + 1

        # Predict and evaluate
        y_pred = best_pipeline.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        accuracies.append(acc)

        print(f"Number of features: {k}, Accuracy: {acc * 100:.2f}%")

    # Store predictions for overall evaluation
    all_test.extend(y_test)
    all_pred.extend(y_pred)
    fold_accuracies.append(accuracies)

    end_time = time.time()
    print(f"Processing time for fold {fold_idx + 1}: {end_time - start_time:.2f} seconds")

# Compute average feature scores
average_feature_scores = []
for feature_idx in feature_score_sums:
    avg_score = feature_score_sums[feature_idx] / feature_counts[feature_idx]
    average_feature_scores.append((feature_idx, avg_score))

# Summary
print("\n=== Overall Results ===")
mean_accuracies = np.mean(fold_accuracies, axis=0)
print("Mean Accuracies for each number of features:", mean_accuracies)

# Plot overall cumulative accuracy across folds
plt.figure(figsize=(10, 6))
plt.step(range(1, max_features + 1), mean_accuracies, where='post', label='Mean Accuracy')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean Accuracy')
plt.title('Cumulative Mean Accuracy Across Folds with Mutual Information')
plt.legend()
plt.grid(True)
plt.show()

# Visualize overall confusion matrix
cm = confusion_matrix(all_test, all_pred)
plt.figure(figsize=(4, 2))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# === Fold 1 ===
# Number of features: 1, Accuracy: 49.97%
# Number of features: 2, Accuracy: 49.91%
# Number of features: 3, Accuracy: 49.90%
# Number of features: 4, Accuracy: 50.09%
# Number of features: 5, Accuracy: 51.08%
# Number of features: 6, Accuracy: 50.87%
# Number of features: 7, Accuracy: 51.70%
# Number of features: 8, Accuracy: 52.18%
# Number of features: 9, Accuracy: 52.23%
# Number of features: 10, Accuracy: 50.97%
# Number of features: 11, Accuracy: 50.89%
# Number of features: 12, Accuracy: 50.69%
# Number of features: 13, Accuracy: 50.67%
# Number of features: 14, Accuracy: 50.34%
# Number of features: 15, Accuracy: 50.44%
# Number of features: 16, Accuracy: 51.33%
# Number of features: 17, Accuracy: 51.88%
# Number of features: 18, Accuracy: 51.71%
# Number of features: 19, Accuracy: 51.92%
# Number of features: 20, Accuracy: 52.08%
# Number of features: 21, Accuracy: 51.66%
# Number of features: 22, Accuracy: 51.93%
# Number of features: 23, Accuracy: 52.05%
# Number of features: 24, Accuracy: 52.02%
# Number of features: 25, Accuracy: 52.14%
# Number of features: 26, Accuracy: 52.26%
# Number of features: 27, Accuracy: 52.55%
# Number of features: 28, Accuracy: 52.14%
# Number of features: 29, Accuracy: 51.25%
# Number of features: 30, Accuracy: 51.64%
# Number of features: 31, Accuracy: 52.26%
# Number of features: 32, Accuracy: 52.12%
# Number of features: 33, Accuracy: 52.48%
# Number of features: 34, Accuracy: 52.65%
# Number of features: 35, Accuracy: 52.49%
# Number of features: 36, Accuracy: 52.60%
# Number of features: 37, Accuracy: 52.36%
# Number of features: 38, Accuracy: 52.37%
# Number of features: 39, Accuracy: 52.36%
# Number of features: 40, Accuracy: 52.72%
# Number of features: 41, Accuracy: 52.51%
# Number of features: 42, Accuracy: 52.57%
# Number of features: 43, Accuracy: 52.64%
# Number of features: 44, Accuracy: 52.70%
# Number of features: 45, Accuracy: 52.74%
# Number of features: 46, Accuracy: 52.97%
# Number of features: 47, Accuracy: 52.65%
# Number of features: 48, Accuracy: 52.74%
# Number of features: 49, Accuracy: 52.54%
# Number of features: 50, Accuracy: 52.66%
# Number of features: 51, Accuracy: 52.11%
# Number of features: 52, Accuracy: 52.12%
# Number of features: 53, Accuracy: 52.23%
# Number of features: 54, Accuracy: 52.45%
# Number of features: 55, Accuracy: 53.60%
# Number of features: 56, Accuracy: 53.17%
# Number of features: 57, Accuracy: 53.16%
# Number of features: 58, Accuracy: 53.00%
# Number of features: 59, Accuracy: 53.01%
# Number of features: 60, Accuracy: 53.09%
# Number of features: 61, Accuracy: 53.07%
# Number of features: 62, Accuracy: 52.83%
# Number of features: 63, Accuracy: 53.39%
# Number of features: 64, Accuracy: 53.50%
# Number of features: 65, Accuracy: 53.44%
# Number of features: 66, Accuracy: 53.42%
# Number of features: 67, Accuracy: 53.27%
# Number of features: 68, Accuracy: 53.20%
# Number of features: 69, Accuracy: 53.29%
# Number of features: 70, Accuracy: 53.20%
# Number of features: 71, Accuracy: 53.41%
# Number of features: 72, Accuracy: 53.23%
# Number of features: 73, Accuracy: 53.53%
# Number of features: 74, Accuracy: 53.47%
# Number of features: 75, Accuracy: 53.44%
# Number of features: 76, Accuracy: 53.56%
# Number of features: 77, Accuracy: 53.23%
# Number of features: 78, Accuracy: 53.50%
# Number of features: 79, Accuracy: 53.51%
# Number of features: 80, Accuracy: 53.29%
# Number of features: 81, Accuracy: 53.37%
# Number of features: 82, Accuracy: 53.50%
# Number of features: 83, Accuracy: 53.50%
# Number of features: 84, Accuracy: 53.06%
# Number of features: 85, Accuracy: 53.07%
# Number of features: 86, Accuracy: 53.09%
# Number of features: 87, Accuracy: 53.00%
# Number of features: 88, Accuracy: 53.18%
# Number of features: 89, Accuracy: 53.35%
# Number of features: 90, Accuracy: 53.38%
# Number of features: 91, Accuracy: 53.28%
# Number of features: 92, Accuracy: 52.38%
# Number of features: 93, Accuracy: 52.57%
# Number of features: 94, Accuracy: 52.56%
# Number of features: 95, Accuracy: 52.63%
# Number of features: 96, Accuracy: 53.36%
# Number of features: 97, Accuracy: 53.32%
# Number of features: 98, Accuracy: 53.70%
# Number of features: 99, Accuracy: 53.69%
# Number of features: 100, Accuracy: 53.73%
# Number of features: 101, Accuracy: 53.69%
# Number of features: 102, Accuracy: 53.81%
# Number of features: 103, Accuracy: 53.71%
# Number of features: 104, Accuracy: 53.72%
# Number of features: 105, Accuracy: 54.00%
# Number of features: 106, Accuracy: 53.79%
# Number of features: 107, Accuracy: 53.72%
# Number of features: 108, Accuracy: 53.89%
# Number of features: 109, Accuracy: 54.38%
# Number of features: 110, Accuracy: 54.37%
# Number of features: 111, Accuracy: 54.03%
# Number of features: 112, Accuracy: 53.94%
# Number of features: 113, Accuracy: 53.96%
# Number of features: 114, Accuracy: 53.91%
# Number of features: 115, Accuracy: 54.11%
# Number of features: 116, Accuracy: 54.47%
# Number of features: 117, Accuracy: 54.10%
# Number of features: 118, Accuracy: 54.10%
# Number of features: 119, Accuracy: 54.14%
# Number of features: 120, Accuracy: 54.03%
# Number of features: 121, Accuracy: 54.12%
# Number of features: 122, Accuracy: 54.03%
# Number of features: 123, Accuracy: 53.98%
# Number of features: 124, Accuracy: 53.92%
# Number of features: 125, Accuracy: 54.16%
# Number of features: 126, Accuracy: 53.96%
# Number of features: 127, Accuracy: 54.08%
# Number of features: 128, Accuracy: 53.96%
# Number of features: 129, Accuracy: 53.96%
# 1it [1:06:38, 3998.47s/it]
# Number of features: 130, Accuracy: 53.72%
# Processing time for fold 1: 3998.29 seconds
#
# === Fold 2 ===
# Number of features: 1, Accuracy: 49.57%
# Number of features: 2, Accuracy: 50.24%
# Number of features: 3, Accuracy: 50.12%
# Number of features: 4, Accuracy: 51.62%
# Number of features: 5, Accuracy: 51.59%
# Number of features: 6, Accuracy: 51.54%
# Number of features: 7, Accuracy: 51.54%
# Number of features: 8, Accuracy: 51.39%
# Number of features: 9, Accuracy: 51.53%
# Number of features: 10, Accuracy: 51.37%
# Number of features: 11, Accuracy: 51.43%
# Number of features: 12, Accuracy: 51.13%
# Number of features: 13, Accuracy: 51.19%
# Number of features: 14, Accuracy: 51.28%
# Number of features: 15, Accuracy: 51.06%
# Number of features: 16, Accuracy: 51.62%
# Number of features: 17, Accuracy: 51.70%
# Number of features: 18, Accuracy: 51.94%
# Number of features: 19, Accuracy: 51.80%
# Number of features: 20, Accuracy: 52.04%
# Number of features: 21, Accuracy: 51.82%
# Number of features: 22, Accuracy: 51.51%
# Number of features: 23, Accuracy: 51.26%
# Number of features: 24, Accuracy: 52.08%
# Number of features: 25, Accuracy: 52.19%
# Number of features: 26, Accuracy: 51.30%
# Number of features: 27, Accuracy: 52.04%
# Number of features: 28, Accuracy: 52.04%
# Number of features: 29, Accuracy: 52.11%
# Number of features: 30, Accuracy: 52.67%
# Number of features: 31, Accuracy: 52.75%
# Number of features: 32, Accuracy: 52.80%
# Number of features: 33, Accuracy: 53.02%
# Number of features: 34, Accuracy: 52.46%
# Number of features: 35, Accuracy: 52.80%
# Number of features: 36, Accuracy: 52.57%
# Number of features: 37, Accuracy: 52.73%
# Number of features: 38, Accuracy: 52.53%
# Number of features: 39, Accuracy: 52.38%
# Number of features: 40, Accuracy: 52.73%
# Number of features: 41, Accuracy: 52.40%
# Number of features: 42, Accuracy: 52.61%
# Number of features: 43, Accuracy: 52.53%
# Number of features: 44, Accuracy: 52.23%
# Number of features: 45, Accuracy: 52.08%
# Number of features: 46, Accuracy: 51.99%
# Number of features: 47, Accuracy: 51.97%
# Number of features: 48, Accuracy: 51.84%
# Number of features: 49, Accuracy: 51.73%
# Number of features: 50, Accuracy: 51.81%
# Number of features: 51, Accuracy: 52.55%
# Number of features: 52, Accuracy: 52.44%
# Number of features: 53, Accuracy: 52.43%
# Number of features: 54, Accuracy: 52.11%
# Number of features: 55, Accuracy: 51.87%
# Number of features: 56, Accuracy: 52.06%
# Number of features: 57, Accuracy: 52.05%
# Number of features: 58, Accuracy: 51.88%
# Number of features: 59, Accuracy: 51.96%
# Number of features: 60, Accuracy: 51.84%
# Number of features: 61, Accuracy: 51.99%
# Number of features: 62, Accuracy: 51.94%
# Number of features: 63, Accuracy: 52.29%
# Number of features: 64, Accuracy: 52.31%
# Number of features: 65, Accuracy: 52.32%
# Number of features: 66, Accuracy: 52.46%
# Number of features: 67, Accuracy: 52.22%
# Number of features: 68, Accuracy: 52.42%
# Number of features: 69, Accuracy: 52.61%
# Number of features: 70, Accuracy: 52.61%
# Number of features: 71, Accuracy: 52.28%
# Number of features: 72, Accuracy: 52.39%
# Number of features: 73, Accuracy: 51.93%
# Number of features: 74, Accuracy: 51.97%
# Number of features: 75, Accuracy: 52.04%
# Number of features: 76, Accuracy: 51.45%
# Number of features: 77, Accuracy: 51.42%
# Number of features: 78, Accuracy: 52.20%
# Number of features: 79, Accuracy: 51.82%
# Number of features: 80, Accuracy: 52.41%
# Number of features: 81, Accuracy: 52.44%
# Number of features: 82, Accuracy: 52.50%
# Number of features: 83, Accuracy: 52.40%
# Number of features: 84, Accuracy: 52.34%
# Number of features: 85, Accuracy: 52.66%
# Number of features: 86, Accuracy: 53.05%
# Number of features: 87, Accuracy: 53.36%
# Number of features: 88, Accuracy: 53.33%
# Number of features: 89, Accuracy: 53.03%
# Number of features: 90, Accuracy: 53.33%
# Number of features: 91, Accuracy: 53.23%
# Number of features: 92, Accuracy: 53.22%
# Number of features: 93, Accuracy: 53.22%
# Number of features: 94, Accuracy: 53.13%
# Number of features: 95, Accuracy: 53.17%
# Number of features: 96, Accuracy: 53.30%
# Number of features: 97, Accuracy: 53.18%
# Number of features: 98, Accuracy: 53.17%
# Number of features: 99, Accuracy: 53.18%
# Number of features: 100, Accuracy: 53.20%
# Number of features: 101, Accuracy: 53.58%
# Number of features: 102, Accuracy: 53.32%
# Number of features: 103, Accuracy: 53.38%
# Number of features: 104, Accuracy: 53.35%
# Number of features: 105, Accuracy: 53.40%
# Number of features: 106, Accuracy: 53.27%
# Number of features: 107, Accuracy: 53.66%
# Number of features: 108, Accuracy: 54.07%
# Number of features: 109, Accuracy: 53.96%
# Number of features: 110, Accuracy: 54.15%
# Number of features: 111, Accuracy: 53.99%
# Number of features: 112, Accuracy: 53.95%
# Number of features: 113, Accuracy: 53.95%
# Number of features: 114, Accuracy: 53.93%
# Number of features: 115, Accuracy: 53.74%
# Number of features: 116, Accuracy: 53.55%
# Number of features: 117, Accuracy: 53.74%
# Number of features: 118, Accuracy: 53.51%
# Number of features: 119, Accuracy: 53.42%
# Number of features: 120, Accuracy: 53.58%
# Number of features: 121, Accuracy: 53.37%
# Number of features: 122, Accuracy: 53.39%
# Number of features: 123, Accuracy: 53.44%
# Number of features: 124, Accuracy: 52.77%
# Number of features: 125, Accuracy: 52.77%
# Number of features: 126, Accuracy: 52.79%
# Number of features: 127, Accuracy: 52.77%
# Number of features: 128, Accuracy: 52.71%
# Number of features: 129, Accuracy: 52.76%
# 2it [2:40:46, 4823.10s/it]
# Number of features: 130, Accuracy: 52.77%
# Processing time for fold 2: 5647.72 seconds
#
# === Overall Results ===
# Mean Accuracies for each number of features: [0.4976913  0.50073316 0.50011378 0.50855947 0.51333545 0.51204252
#  0.51620075 0.51782856 0.51878548 0.51170346 0.51159171 0.50905964
#  0.50934136 0.50810614 0.50748549 0.51474064 0.5178883  0.51822811
#  0.51861994 0.52058933 0.51744015 0.51721184 0.51653474 0.52053365
#  0.52160244 0.51777136 0.52294941 0.52087029 0.51676901 0.52155169
#  0.52503651 0.52464379 0.52751201 0.52553895 0.52649814 0.52582117
#  0.5254296  0.52452837 0.52368371 0.52722776 0.52452685 0.52593407
#  0.52587699 0.52463734 0.52412996 0.52480326 0.52311723 0.52289094
#  0.52137261 0.52238496 0.52329226 0.52284159 0.523291   0.5227816
#  0.52733052 0.52615263 0.52604012 0.52440864 0.52485907 0.52463291
#  0.52530899 0.52384735 0.52840286 0.52902123 0.52879659 0.52936003
#  0.52744683 0.52812342 0.52953038 0.52908084 0.52840273 0.52806685
#  0.52727496 0.52721928 0.52738861 0.52507814 0.52322341 0.52845804
#  0.52665571 0.52851664 0.52907894 0.52997865 0.52947178 0.52699868
#  0.52863181 0.53071536 0.53178643 0.53257287 0.53189514 0.53358433
#  0.53257173 0.52802002 0.52897529 0.52846855 0.52897466 0.53330299
#  0.53245871 0.53431294 0.53431306 0.53465047 0.53634055 0.53566333
#  0.53543919 0.53532643 0.53701283 0.53526935 0.53690336 0.53977373
#  0.54173932 0.54258423 0.54011    0.5394915  0.53954769 0.53921028
#  0.53926432 0.54010506 0.53920813 0.53808175 0.53779978 0.53808251
#  0.53746199 0.53712509 0.5370694  0.53346562 0.53464566 0.53374684
#  0.53425231 0.5333526  0.53357788 0.53245416]

# %%
average_feature_scores_indices = []
average_feature_scores_list=[]
for i, j in average_feature_scores:
    average_feature_scores_indices.append(i)
average_feature_scores_indices
# Out:
# [21,
#  116,
#  120,
#  118,
#  112,
#  19,
#  114,
#  110,
#  124,
#  90,
#  122,
#  91,
#  126,
#  128,
#  4,
#  97,
#  48,
#  2,
#  6,
#  49,
#  55,
#  54,
#  63,
#  40,
#  41,
#  64,
#  8,
#  10,
#  42,
#  46,
#  83,
#  9,
#  0,
#  3,
#  80,
#  5,
#  43,
#  14,
#  1,
#  92,
#  76,
#  111,
#  82,
#  28,
#  24,
#  25,
#  27,
#  17,
#  101,
#  94,
#  22,
#  36,
#  66,
#  13,
#  95,
#  70,
#  53,
#  52,
#  79,
#  104,
#  47,
#  15,
#  99,
#  12,
#  7,
#  23,
#  73,
#  16,
#  34,
#  57,
#  60,
#  11,
#  78,
#  117,
#  103,
#  86,
#  35,
#  67,
#  102,
#  58,
#  75,
#  62,
#  106,
#  51,
#  39,
#  61,
#  81,
#  93,
#  108,
#  77,
#  38,
#  105,
#  31,
#  59,
#  56,
#  44,
#  68,
#  125,
#  74,
#  37,
#  26,
#  29,
#  96,
#  129,
#  45,
#  98,
#  107,
#  65,
#  87,
#  121,
#  109,
#  50,
#  89,
#  88,
#  113,
#  20,
#  115,
#  30,
#  32,
#  33,
#  69,
#  127,
#  123,
#  119,
#  100,
#  71,
#  72,
#  84,
#  85,
#  18]

# %%
for i in average_feature_scores_indices:
    average_feature_scores_list.append(df_features.columns[i])
average_feature_scores_list
# Out:
# ['min_fall_slope',
#  'dwt_cD4_min',
#  'dwt_cD3_min',
#  'dwt_cD3_max',
#  'dwt_cA4_min',
#  'max_rise_slope',
#  'dwt_cD4_max',
#  'dwt_cA4_max',
#  'dwt_cD2_min',
#  'min',
#  'dwt_cD2_max',
#  'max',
#  'dwt_cD1_max',
#  'dwt_cD1_min',
#  'iqr_time_diff_onset_dic',
#  'zero_cross',
#  'MedianNN',
#  'iqr_time_diff_onset_sys',
#  'iqr_time_diff_dic_ends',
#  'IQRNN',
#  'PNN50',
#  'NN50',
#  'ApEn',
#  'ab_duration',
#  'bc_duration',
#  'LZC',
#  'avg_time_diff_p1_dia',
#  'pulse_rate',
#  'bd_duration',
#  'Mean_IBI',
#  'power_second_harmonic',
#  'avg_time_diff_p2_dia',
#  'avg_time_diff_sys_dia',
#  'avg_time_diff_onset_dic',
#  'LZC_PPG',
#  'avg_time_diff_dic_ends',
#  'total_wave_duration',
#  'avg_reflection_index',
#  'avg_time_diff_onset_sys',
#  'mean',
#  'MSE_PermEn_τ4',
#  'dwt_cA4_mean',
#  'power_first_harmonic',
#  'avg_total_area_rate',
#  'avg_IPA',
#  'avg_area_under_pulse',
#  'avg_fall_area_rate',
#  'ratio_p1_p2',
#  'median',
#  'mean_energy',
#  'avg_systolic_area',
#  'c/a_ratio',
#  'MSE_ApEn_τ1',
#  'avg_augmentation_index',
#  'rms',
#  'MSE_PermEn_τ2',
#  'SDSD',
#  'CVSD',
#  'MSE_PermEn_τ5',
#  'moment-5',
#  'SDNN',
#  'avg_reflection_index_p1',
#  'skewness',
#  'std_pulse_wave_amplitude',
#  'avg_t_ratio',
#  'avg_diastolic_area',
#  'MSE_PermEn_τ3',
#  'avg_reflection_index_p2',
#  'f_amp',
#  'LF_Log_Power',
#  'LF_Norm',
#  'avg_pulse_wave_amplitude',
#  'MSE_ApEn_τ5',
#  'dwt_cD4_std',
#  'moment-4',
#  'standardised_second_harmonic',
#  'b/a_ratio',
#  'MSE_PermEn_τ1',
#  'moment-3',
#  'HF_Log_Power',
#  'MSE_ApEn_τ4',
#  'LF_HF_Ratio',
#  'diff_1',
#  'RMSSD',
#  'f/a_ratio',
#  'HF_Norm',
#  'power_fundamental',
#  'mean_abs',
#  'diff_1_kstd',
#  'MSE_SampEn_τ5',
#  'e/a_ratio',
#  'moment-6',
#  'c_amp',
#  'Total_Power',
#  'VLF_Log_Power',
#  'aging_index',
#  'MSE_SampEn_τ2',
#  'dwt_cD2_std',
#  'MSE_SampEn_τ4',
#  'd/a_ratio',
#  'avg_rise_area_rate',
#  'a_amp',
#  'std',
#  'dwt_cD1_std',
#  'vascular_index',
#  'mad',
#  'diff_2',
#  'MSE_SampEn_τ1',
#  'FHF',
#  'dwt_cD3_std',
#  'diff_2_kstd',
#  'CVNN',
#  'SHFH',
#  'SHF',
#  'dwt_cA4_std',
#  'avg_fall_slope',
#  'dwt_cD4_mean',
#  'b_amp',
#  'd_amp',
#  'e_amp',
#  'MSE_ApEn_τ2',
#  'dwt_cD1_mean',
#  'dwt_cD2_mean',
#  'dwt_cD3_mean',
#  'kurtosis',
#  'MSE_SampEn_τ3',
#  'MSE_ApEn_τ3',
#  'standardised_power_fundamental',
#  'standardised_first_harmonic',
#  'avg_rise_slope']

# %%
for i in range(len(average_feature_scores)):
    score_value = average_feature_scores[i][1]
    average_feature_scores[i] = (average_feature_scores_indices[i],score_value)
average_feature_scores
# Out:
# [(21, 0.40732621970615257),
#  (116, 0.3859072396772122),
#  (120, 0.3865355190518059),
#  (118, 0.36271673891147194),
#  (112, 0.35931631797145824),
#  (19, 0.35960162213057534),
#  (114, 0.35791767081247394),
#  (110, 0.3438831131839194),
#  (124, 0.3396638403844392),
#  (90, 0.32330980806203974),
#  (122, 0.3195330581203086),
#  (91, 0.30334778326311934),
#  (126, 0.16718985168785555),
#  (128, 0.13799562903997833),
#  (4, 0.13585565437764163),
#  (97, 0.12531100634487832),
#  (48, 0.119038247319095),
#  (2, 0.11625594060371747),
#  (6, 0.11770431886462591),
#  (49, 0.1069337478997855),
#  (55, 0.10776633802075777),
#  (54, 0.10153787401531342),
#  (63, 0.08661110464870025),
#  (40, 0.07830725279002163),
#  (41, 0.07602369993919184),
#  (64, 0.060535540236874276),
#  (8, 0.059731857457854115),
#  (10, 0.06642505868365942),
#  (42, 0.055078021958425316),
#  (46, 0.06128746309203701),
#  (83, 0.05886462346477163),
#  (9, 0.05890200218431934),
#  (0, 0.05969712653145104),
#  (3, 0.04676757211463245),
#  (80, 0.043162813945866366),
#  (5, 0.038058238677946596),
#  (43, 0.03987809366980465),
#  (14, 0.03734437183126516),
#  (1, 0.03711486890303042),
#  (92, 0.028209252323518234),
#  (76, 0.02154047941262517),
#  (111, 0.021194605308456155),
#  (82, 0.021741257738786327),
#  (28, 0.024920817893338162),
#  (24, 0.018647886490641773),
#  (25, 0.018706349649836692),
#  (27, 0.015873300242381327),
#  (17, 0.014365295164136732),
#  (101, 0.021946593793183585),
#  (94, 0.013703898372649568),
#  (22, 0.013515800774134626),
#  (36, 0.013932302261703597),
#  (66, 0.013097326111332864),
#  (13, 0.01737716839211115),
#  (95, 0.013260462548108542),
#  (70, 0.01411212057399063),
#  (53, 0.017456779066026405),
#  (52, 0.011963103393726625),
#  (79, 0.013057112220250048),
#  (104, 0.015199780607600107),
#  (47, 0.013569807635064707),
#  (15, 0.010465880627771306),
#  (99, 0.014329032168738997),
#  (12, 0.00951224533506525),
#  (7, 0.00933919722137089),
#  (23, 0.01622829189187446),
#  (73, 0.008430486149726071),
#  (16, 0.009139163386569536),
#  (34, 0.01041384493107614),
#  (57, 0.005009279588274288),
#  (60, 0.00526091152157008),
#  (11, 0.013506625342317396),
#  (78, 0.008041163271552318),
#  (117, 0.008943284870547543),
#  (103, 0.013683912972045699),
#  (86, 0.009923448240811924),
#  (35, 0.00808457327930718),
#  (67, 0.009949431378165802),
#  (102, 0.013188001361296367),
#  (58, 0.006334865676384518),
#  (75, 0.009036296688240866),
#  (62, 0.004811375278398681),
#  (106, 0.007143982023607309),
#  (51, 0.01712490729403705),
#  (39, 0.007110951794563485),
#  (61, 0.005152220392831552),
#  (81, 0.004143576638413678),
#  (93, 0.0057859570397927685),
#  (108, 0.014588215608948097),
#  (77, 0.01068885263198531),
#  (38, 0.008364598365401696),
#  (105, 0.005433732464251258),
#  (31, 0.006372537245285764),
#  (59, 0.011194889295473786),
#  (56, 0.005559312025791455),
#  (44, 0.00905988175057841),
#  (68, 0.007734560632277237),
#  (125, 0.01874050106754531),
#  (74, 0.005359512835624162),
#  (37, 0.0046624263324593455),
#  (26, 0.0071822681181420225),
#  (29, 0.007281970475462707),
#  (96, 0.009625097230742204),
#  (129, 0.0036083788512856004),
#  (45, 0.016144870694901097),
#  (98, 0.0061813468447001274),
#  (107, 0.009747130512247695),
#  (65, 0.012414767181295456),
#  (87, 0.002843816459643562),
#  (121, 0.010523640204999267),
#  (109, 0.01705238877869208),
#  (50, 0.014197212899034759),
#  (89, 0.002424402957257445),
#  (88, 0.008610975022979556),
#  (113, 0.0027839251128935296),
#  (20, 0.002179350827594173),
#  (115, 0.0015798579486247433),
#  (30, 0.017826436180217443),
#  (32, 0.014591232111510097),
#  (33, 0.0006783949354975426),
#  (69, 0.0010930872298331737),
#  (127, 0.004399902542557602),
#  (123, 0.0),
#  (119, 0.0013791616517391026),
#  (100, 0.010501580945591794),
#  (71, 0.0),
#  (72, 0.008260713002728595),
#  (84, 0.001856502926943778),
#  (85, 0.0),
#  (18, 0.007897432063771826)]

# %%
df = pd.DataFrame(average_feature_scores)
df.rename(columns = {0:'features',1:'mi_scores'}, inplace=True)
df.to_csv('feature_with_mi_scores_svm.csv')
df
# Out:
#      features  mi_scores
# 0          21   0.407326
# 1         116   0.385907
# 2         120   0.386536
# 3         118   0.362717
# 4         112   0.359316
# ..        ...        ...
# 125        71   0.000000
# 126        72   0.008261
# 127        84   0.001857
# 128        85   0.000000
# 129        18   0.007897
#
# [130 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.step(range(1, max_features + 1), mean_accuracies, where='post', label='Mean Accuracy')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean Accuracy')
plt.title('Cumulative Mean Accuracy Across Folds')
plt.legend()
plt.grid(True)
plt.savefig("step_plot_mi_scores_xvm.pdf",bbox_inches='tight')

plt.show()
