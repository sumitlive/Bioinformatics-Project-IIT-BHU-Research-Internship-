# %%
import pandas as pd
import numpy as np
X_resampled = np.load("X_resampled.npy")
y_resampled = np.load("y_resampled.npy")
groups_resampled = np.load("groups_resampled.npy")
df_features = pd.read_csv("Features_130.csv", index_col=0)

# %%
import numpy as np
from collections import Counter
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedGroupKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.metrics import accuracy_score, confusion_matrix
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint, uniform

# Cross-validation setup
sgkf = StratifiedGroupKFold(n_splits=2, shuffle=True, random_state=206)  # Use n_splits=5 for optimal value

# Initialize variables
fold_accuracies = []
all_test = []
all_pred = []
feature_score_sums = {}
feature_counts = {}

# Splitting according to CV strategy
for fold_idx, (train_idx, test_idx) in tqdm(enumerate(sgkf.split(X_resampled, y_resampled, groups_resampled))):
    print(f"\n=== Fold {fold_idx + 1} ===")
    start_time = time.time()

    # Split into train and test data
    X_train, y_train = X_resampled[train_idx], y_resampled[train_idx]
    X_test, y_test = X_resampled[test_idx], y_resampled[test_idx]

    # List to store accuracy for each number of features
    accuracies = []
    
    max_features = min(130, X_train.shape[1])
        
        
#     # Compute mutual information scores
#     scaler = StandardScaler()
#     X_train_scaled = scaler.fit_transform(X_train)
    
#     # Compute mutual information scores
#     mi_scores = mutual_info_classif(X_train_scaled, y_train, random_state=42)
    for k in range(1, max_features + 1):
        # Define the pipeline
        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('feature_selector', SelectKBest(score_func=mutual_info_classif, k=k)),
            ('classifier', RandomForestClassifier(random_state=42))
        ])

        # Define hyperparameter distributions for RandomizedSearchCV
        param_distributions = {
            'classifier__n_estimators': randint(100, 500),
            'classifier__max_depth': randint(3, 10),
            'classifier__min_samples_split': randint(2, 20),
            'classifier__min_samples_leaf': randint(1, 10),
            'classifier__max_features': uniform(0.1, 0.9)  # Range from 0.1 to 1.0
        }

        # Set up RandomizedSearchCV
        random_search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_distributions,
            n_iter=1,  # Adjust as needed, e.g., 10 for better tuning
            cv=3,
            scoring='accuracy',
            n_jobs=-1,
            random_state=42
        )

        # Fit RandomizedSearchCV
        random_search.fit(X_train, y_train)

        # Get the best pipeline
        best_pipeline = random_search.best_estimator_

        # Get the feature selector
        feature_selector = best_pipeline.named_steps['feature_selector']

        # Get the mutual information scores
        mi_scores = feature_selector.scores_

        # Get the selected feature indices
        selected_features = feature_selector.get_support(indices=True)

        # Get the mi_scores for selected features
        selected_mi_scores = mi_scores[selected_features]

        # Update cumulative scores and counts
        for idx, score in zip(selected_features, selected_mi_scores):
            feature_score_sums[idx] = feature_score_sums.get(idx, 0) + score
            feature_counts[idx] = feature_counts.get(idx, 0) + 1

        # Predict and evaluate
        y_pred = best_pipeline.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        accuracies.append(acc)

        print(f"Number of features: {k}, Accuracy: {acc * 100:.2f}%")

    # Store predictions for overall evaluation
    all_test.extend(y_test)
    all_pred.extend(y_pred)
    fold_accuracies.append(accuracies)

    end_time = time.time()
    print(f"Processing time for fold {fold_idx + 1}: {end_time - start_time:.2f} seconds")

# Compute average feature scores
average_feature_scores = []
for feature_idx in feature_score_sums:
    avg_score = feature_score_sums[feature_idx] / feature_counts[feature_idx]
    average_feature_scores.append((feature_idx, avg_score))

# Summary
print("\n=== Overall Results ===")
mean_accuracies = np.mean(fold_accuracies, axis=0)
print("Mean Accuracies for each number of features:", mean_accuracies)

# Plot overall cumulative accuracy across folds
plt.figure(figsize=(10, 6))
plt.step(range(1, max_features + 1), mean_accuracies, where='post', label='Mean Accuracy')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean Accuracy')
plt.title('Cumulative Mean Accuracy Across Folds with Mutual Information')
plt.legend()
plt.grid(True)
plt.show()

# Visualize overall confusion matrix
cm = confusion_matrix(all_test, all_pred)
plt.figure(figsize=(4, 2))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# === Fold 1 ===
# Number of features: 1, Accuracy: 52.99%
# Number of features: 2, Accuracy: 53.25%
# Number of features: 3, Accuracy: 54.23%
# Number of features: 4, Accuracy: 53.37%
# Number of features: 5, Accuracy: 56.69%
# Number of features: 6, Accuracy: 58.07%
# Number of features: 7, Accuracy: 58.09%
# Number of features: 8, Accuracy: 59.15%
# Number of features: 9, Accuracy: 60.07%
# Number of features: 10, Accuracy: 60.07%
# Number of features: 11, Accuracy: 59.81%
# Number of features: 12, Accuracy: 60.08%
# Number of features: 13, Accuracy: 59.95%
# Number of features: 14, Accuracy: 60.83%
# Number of features: 15, Accuracy: 61.09%
# Number of features: 16, Accuracy: 60.91%
# Number of features: 17, Accuracy: 61.65%
# Number of features: 18, Accuracy: 61.73%
# Number of features: 19, Accuracy: 61.65%
# Number of features: 20, Accuracy: 62.05%
# Number of features: 21, Accuracy: 62.37%
# Number of features: 22, Accuracy: 62.70%
# Number of features: 23, Accuracy: 63.05%
# Number of features: 24, Accuracy: 63.09%
# Number of features: 25, Accuracy: 62.97%
# Number of features: 26, Accuracy: 62.97%
# Number of features: 27, Accuracy: 62.97%
# Number of features: 28, Accuracy: 63.12%
# Number of features: 29, Accuracy: 63.31%
# Number of features: 30, Accuracy: 62.91%
# Number of features: 31, Accuracy: 63.51%
# Number of features: 32, Accuracy: 63.44%
# Number of features: 33, Accuracy: 63.24%
# Number of features: 34, Accuracy: 63.35%
# Number of features: 35, Accuracy: 62.98%
# Number of features: 36, Accuracy: 63.04%
# Number of features: 37, Accuracy: 63.07%
# Number of features: 38, Accuracy: 63.25%
# Number of features: 39, Accuracy: 63.97%
# Number of features: 40, Accuracy: 63.24%
# Number of features: 41, Accuracy: 63.54%
# Number of features: 42, Accuracy: 62.97%
# Number of features: 43, Accuracy: 63.00%
# Number of features: 44, Accuracy: 62.99%
# Number of features: 45, Accuracy: 63.41%
# Number of features: 46, Accuracy: 63.35%
# Number of features: 47, Accuracy: 63.21%
# Number of features: 48, Accuracy: 63.45%
# Number of features: 49, Accuracy: 62.94%
# Number of features: 50, Accuracy: 63.39%
# Number of features: 51, Accuracy: 63.60%
# Number of features: 52, Accuracy: 63.43%
# Number of features: 53, Accuracy: 63.32%
# Number of features: 54, Accuracy: 63.91%
# Number of features: 55, Accuracy: 63.68%
# Number of features: 56, Accuracy: 63.47%
# Number of features: 57, Accuracy: 63.65%
# Number of features: 58, Accuracy: 63.63%
# Number of features: 59, Accuracy: 63.72%
# Number of features: 60, Accuracy: 63.55%
# Number of features: 61, Accuracy: 63.73%
# Number of features: 62, Accuracy: 63.71%
# Number of features: 63, Accuracy: 64.07%
# Number of features: 64, Accuracy: 63.88%
# Number of features: 65, Accuracy: 63.89%
# Number of features: 66, Accuracy: 64.27%
# Number of features: 67, Accuracy: 64.33%
# Number of features: 68, Accuracy: 64.33%
# Number of features: 69, Accuracy: 64.36%
# Number of features: 70, Accuracy: 64.50%
# Number of features: 71, Accuracy: 63.98%
# Number of features: 72, Accuracy: 64.18%
# Number of features: 73, Accuracy: 63.76%
# Number of features: 74, Accuracy: 64.03%
# Number of features: 75, Accuracy: 63.55%
# Number of features: 76, Accuracy: 63.86%
# Number of features: 77, Accuracy: 63.96%
# Number of features: 78, Accuracy: 63.55%
# Number of features: 79, Accuracy: 63.89%
# Number of features: 80, Accuracy: 64.00%
# Number of features: 81, Accuracy: 63.77%
# Number of features: 82, Accuracy: 63.56%
# Number of features: 83, Accuracy: 64.24%
# Number of features: 84, Accuracy: 63.63%
# Number of features: 85, Accuracy: 64.44%
# Number of features: 86, Accuracy: 64.04%
# Number of features: 87, Accuracy: 63.96%
# Number of features: 88, Accuracy: 64.45%
# Number of features: 89, Accuracy: 64.90%
# Number of features: 90, Accuracy: 64.04%
# Number of features: 91, Accuracy: 64.83%
# Number of features: 92, Accuracy: 64.17%
# Number of features: 93, Accuracy: 64.41%
# Number of features: 94, Accuracy: 65.09%
# Number of features: 95, Accuracy: 64.37%
# Number of features: 96, Accuracy: 64.49%
# Number of features: 97, Accuracy: 64.23%
# Number of features: 98, Accuracy: 64.83%
# Number of features: 99, Accuracy: 64.71%
# Number of features: 100, Accuracy: 64.58%
# Number of features: 101, Accuracy: 64.64%
# Number of features: 102, Accuracy: 64.87%
# Number of features: 103, Accuracy: 65.08%
# Number of features: 104, Accuracy: 64.51%
# Number of features: 105, Accuracy: 64.69%
# Number of features: 106, Accuracy: 65.09%
# Number of features: 107, Accuracy: 65.06%
# Number of features: 108, Accuracy: 64.50%
# Number of features: 109, Accuracy: 64.95%
# Number of features: 110, Accuracy: 64.89%
# Number of features: 111, Accuracy: 65.10%
# Number of features: 112, Accuracy: 64.98%
# Number of features: 113, Accuracy: 65.50%
# Number of features: 114, Accuracy: 65.44%
# Number of features: 115, Accuracy: 64.86%
# Number of features: 116, Accuracy: 64.97%
# Number of features: 117, Accuracy: 65.34%
# Number of features: 118, Accuracy: 65.00%
# Number of features: 119, Accuracy: 65.25%
# Number of features: 120, Accuracy: 65.35%
# Number of features: 121, Accuracy: 65.35%
# Number of features: 122, Accuracy: 64.77%
# Number of features: 123, Accuracy: 65.37%
# Number of features: 124, Accuracy: 65.32%
# Number of features: 125, Accuracy: 65.68%
#  0.57757274 0.58657188 0.58881426 0.59377033 0.5927595  0.5975999
#  0.59563025 0.60068896 0.60237562 0.60739004 0.6032704  0.60704288
#  0.6050726  0.60968633 0.61435713 0.61390291 0.61496905 0.61924879
#  0.61778588 0.6166595  0.61772957 0.62014964 0.62009117 0.62324946
#  0.62329907 0.62403198 0.62183781 0.62183655 0.62251655 0.62533187
#  0.62465566 0.63028554 0.63236124 0.62972247 0.63090175 0.62781066
#  0.62854243 0.62904943 0.62904475 0.62932697 0.62870911 0.62679148
#  0.62595252 0.62842549 0.62814149 0.62887554 0.62589189 0.62937696
#  0.62774637 0.62690386 0.62757767 0.62774688 0.62949175 0.6266777
#  0.62847788 0.6271828  0.63100844 0.63123587 0.63123574 0.63190727
#  0.63201927 0.63432835 0.63331423 0.63241161 0.63185424 0.63044399
#  0.63039248 0.62875619 0.62690298 0.62898336 0.6280248  0.62752249
#  0.63039096 0.63016442 0.6308429  0.62898665 0.6308939  0.62943645
#  0.63472132 0.63207888 0.62965805 0.63218684 0.63567355 0.63044563
#  0.63449161 0.62988092 0.63286317 0.63578404 0.63337042 0.63252437
#  0.63275256 0.63528008 0.63421141 0.63393133 0.63466272 0.63297062
#  0.63572784 0.63494583 0.63364847 0.63623459 0.63550282 0.63218633
#  0.63370188 0.63623687 0.63420698 0.6334199  0.63769432 0.63685017
#  0.63246387 0.63679917 0.63640076 0.63572873 0.63713392 0.63504898
#  0.63814652 0.63218329 0.63797731 0.6372458  0.63797389 0.6351644
#  0.63415015 0.63803312 0.63640329 0.63932897]

# %%
average_feature_scores_indices = []
average_feature_scores_list=[]
for i, j in average_feature_scores:
    average_feature_scores_indices.append(i)
average_feature_scores_indices
# Out:
# [21,
#  116,
#  120,
#  118,
#  112,
#  19,
#  114,
#  110,
#  124,
#  90,
#  122,
#  91,
#  126,
#  4,
#  128,
#  48,
#  97,
#  2,
#  6,
#  55,
#  49,
#  54,
#  40,
#  63,
#  41,
#  10,
#  42,
#  8,
#  64,
#  46,
#  83,
#  9,
#  0,
#  80,
#  3,
#  43,
#  5,
#  14,
#  1,
#  92,
#  82,
#  76,
#  111,
#  28,
#  25,
#  24,
#  27,
#  17,
#  101,
#  94,
#  22,
#  36,
#  66,
#  70,
#  79,
#  13,
#  95,
#  53,
#  52,
#  104,
#  47,
#  15,
#  99,
#  12,
#  7,
#  23,
#  16,
#  73,
#  60,
#  61,
#  34,
#  78,
#  56,
#  11,
#  117,
#  103,
#  67,
#  35,
#  102,
#  57,
#  86,
#  58,
#  75,
#  106,
#  51,
#  39,
#  77,
#  93,
#  108,
#  105,
#  31,
#  38,
#  62,
#  59,
#  44,
#  68,
#  125,
#  74,
#  81,
#  37,
#  26,
#  29,
#  129,
#  96,
#  89,
#  107,
#  45,
#  98,
#  65,
#  121,
#  87,
#  109,
#  50,
#  88,
#  113,
#  115,
#  20,
#  30,
#  32,
#  33,
#  69,
#  123,
#  127,
#  119,
#  100,
#  85,
#  84,
#  71,
#  72,
#  18]

# %%
for i in average_feature_scores_indices:
    average_feature_scores_list.append(df_features.columns[i])
average_feature_scores_list
# Out:
# ['min_fall_slope',
#  'dwt_cD4_min',
#  'dwt_cD3_min',
#  'dwt_cD3_max',
#  'dwt_cA4_min',
#  'max_rise_slope',
#  'dwt_cD4_max',
#  'dwt_cA4_max',
#  'dwt_cD2_min',
#  'min',
#  'dwt_cD2_max',
#  'max',
#  'dwt_cD1_max',
#  'iqr_time_diff_onset_dic',
#  'dwt_cD1_min',
#  'MedianNN',
#  'zero_cross',
#  'iqr_time_diff_onset_sys',
#  'iqr_time_diff_dic_ends',
#  'PNN50',
#  'IQRNN',
#  'NN50',
#  'ab_duration',
#  'ApEn',
#  'bc_duration',
#  'pulse_rate',
#  'bd_duration',
#  'avg_time_diff_p1_dia',
#  'LZC',
#  'Mean_IBI',
#  'power_second_harmonic',
#  'avg_time_diff_p2_dia',
#  'avg_time_diff_sys_dia',
#  'LZC_PPG',
#  'avg_time_diff_onset_dic',
#  'total_wave_duration',
#  'avg_time_diff_dic_ends',
#  'avg_reflection_index',
#  'avg_time_diff_onset_sys',
#  'mean',
#  'power_first_harmonic',
#  'MSE_PermEn_τ4',
#  'dwt_cA4_mean',
#  'avg_total_area_rate',
#  'avg_area_under_pulse',
#  'avg_IPA',
#  'avg_fall_area_rate',
#  'ratio_p1_p2',
#  'median',
#  'mean_energy',
#  'avg_systolic_area',
#  'c/a_ratio',
#  'MSE_ApEn_τ1',
#  'MSE_PermEn_τ2',
#  'MSE_PermEn_τ5',
#  'avg_augmentation_index',
#  'rms',
#  'SDSD',
#  'CVSD',
#  'moment-5',
#  'SDNN',
#  'avg_reflection_index_p1',
#  'skewness',
#  'std_pulse_wave_amplitude',
#  'avg_t_ratio',
#  'avg_diastolic_area',
#  'avg_reflection_index_p2',
#  'MSE_PermEn_τ3',
#  'LF_Norm',
#  'HF_Norm',
#  'f_amp',
#  'MSE_ApEn_τ5',
#  'VLF_Log_Power',
#  'avg_pulse_wave_amplitude',
#  'dwt_cD4_std',
#  'moment-4',
#  'MSE_PermEn_τ1',
#  'b/a_ratio',
#  'moment-3',
#  'LF_Log_Power',
#  'standardised_second_harmonic',
#  'HF_Log_Power',
#  'MSE_ApEn_τ4',
#  'diff_1',
#  'RMSSD',
#  'f/a_ratio',
#  'MSE_SampEn_τ5',
#  'mean_abs',
#  'diff_1_kstd',
#  'moment-6',
#  'c_amp',
#  'e/a_ratio',
#  'LF_HF_Ratio',
#  'Total_Power',
#  'aging_index',
#  'MSE_SampEn_τ2',
#  'dwt_cD2_std',
#  'MSE_SampEn_τ4',
#  'power_fundamental',
#  'd/a_ratio',
#  'avg_rise_area_rate',
#  'a_amp',
#  'dwt_cD1_std',
#  'std',
#  'SHFH',
#  'diff_2',
#  'vascular_index',
#  'mad',
#  'MSE_SampEn_τ1',
#  'dwt_cD3_std',
#  'FHF',
#  'diff_2_kstd',
#  'CVNN',
#  'SHF',
#  'dwt_cA4_std',
#  'dwt_cD4_mean',
#  'avg_fall_slope',
#  'b_amp',
#  'd_amp',
#  'e_amp',
#  'MSE_ApEn_τ2',
#  'dwt_cD2_mean',
#  'dwt_cD1_mean',
#  'dwt_cD3_mean',
#  'kurtosis',
#  'standardised_first_harmonic',
#  'standardised_power_fundamental',
#  'MSE_SampEn_τ3',
#  'MSE_ApEn_τ3',
#  'avg_rise_slope']

# %%
for i in range(len(average_feature_scores)):
    score_value = average_feature_scores[i][1]
    average_feature_scores[i] = (average_feature_scores_indices[i],score_value)
average_feature_scores
# Out:
# [(21, 0.4073260035815265),
#  (116, 0.385906583242207),
#  (120, 0.38653606493166964),
#  (118, 0.36271762832960275),
#  (112, 0.3593178923714401),
#  (19, 0.35960117515445816),
#  (114, 0.3579172194678732),
#  (110, 0.3438835720910637),
#  (124, 0.3396645307558342),
#  (90, 0.32318105210531484),
#  (122, 0.31953149352808186),
#  (91, 0.3034060273818112),
#  (126, 0.16718961304806415),
#  (4, 0.13602940387400517),
#  (128, 0.13797394770887578),
#  (48, 0.11949925467151425),
#  (97, 0.12497954719524139),
#  (2, 0.1171935188734918),
#  (6, 0.11775774646098597),
#  (55, 0.10817820940495143),
#  (49, 0.10689963122615247),
#  (54, 0.10175721107157493),
#  (40, 0.07866424917796506),
#  (63, 0.08639918196918653),
#  (41, 0.0763555215746033),
#  (10, 0.06700022120229311),
#  (42, 0.054786190688922584),
#  (8, 0.059190567404920486),
#  (64, 0.06065938441042086),
#  (46, 0.06163250364247925),
#  (83, 0.05856000993730937),
#  (9, 0.05936287780801007),
#  (0, 0.06019125467216645),
#  (80, 0.044159505846326594),
#  (3, 0.04696840598494649),
#  (43, 0.03997481470641991),
#  (5, 0.03773328717261305),
#  (14, 0.03729720264496793),
#  (1, 0.037408380989922545),
#  (92, 0.028209252323518234),
#  (82, 0.021876746375088685),
#  (76, 0.021487285443783196),
#  (111, 0.02118129570993458),
#  (28, 0.024920817893338162),
#  (25, 0.018706349649836692),
#  (24, 0.018659158915603064),
#  (27, 0.01605317371354783),
#  (17, 0.01436435651429067),
#  (101, 0.021946593793183585),
#  (94, 0.013703898372649568),
#  (22, 0.013515800774134626),
#  (36, 0.013932302261703597),
#  (66, 0.013097326111332864),
#  (70, 0.014169759701210123),
#  (79, 0.013042546147946615),
#  (13, 0.017401712884044934),
#  (95, 0.013268927952965947),
#  (53, 0.0174452484572745),
#  (52, 0.011941344823871672),
#  (104, 0.015199780607600107),
#  (47, 0.013586774700420738),
#  (15, 0.01049668064756944),
#  (99, 0.014329032168738997),
#  (12, 0.009591058517020091),
#  (7, 0.009377337581452132),
#  (23, 0.016200184617091846),
#  (16, 0.009126757100721274),
#  (73, 0.00838922548319769),
#  (60, 0.005115247977165756),
#  (61, 0.0036253744246649766),
#  (34, 0.01041384493107614),
#  (78, 0.008028599398396865),
#  (56, 0.005970476303687195),
#  (11, 0.013540339460298579),
#  (117, 0.008948236367312358),
#  (103, 0.013753522285131754),
#  (67, 0.009911701328681754),
#  (35, 0.00808457327930718),
#  (102, 0.013227715884454514),
#  (57, 0.005546563257959547),
#  (86, 0.009948983994039167),
#  (58, 0.006374062334006839),
#  (75, 0.009045557230070752),
#  (106, 0.007143982023607309),
#  (51, 0.01695200968145289),
#  (39, 0.007110951794563485),
#  (77, 0.0106705670997172),
#  (93, 0.005811604440693099),
#  (108, 0.014588215608948097),
#  (105, 0.005524943000871065),
#  (31, 0.0063633521591847505),
#  (38, 0.008392939239311994),
#  (62, 0.00480233993767213),
#  (59, 0.01126311689783723),
#  (44, 0.009021180073547137),
#  (68, 0.007712655245030915),
#  (125, 0.01874050106754531),
#  (74, 0.005381090202057208),
#  (81, 0.0045297632951009185),
#  (37, 0.004638444117042503),
#  (26, 0.0071822681181420225),
#  (29, 0.007281970475462707),
#  (129, 0.003579873907372244),
#  (96, 0.00972584684538158),
#  (89, 0.002826883343394467),
#  (107, 0.009747130512247695),
#  (45, 0.016285469474709588),
#  (98, 0.0061813468447001274),
#  (65, 0.012327653864535973),
#  (121, 0.01044875907551618),
#  (87, 0.002725518104977336),
#  (109, 0.016808399082062962),
#  (50, 0.014198239989209677),
#  (88, 0.008700093172425266),
#  (113, 0.002790215775625911),
#  (115, 0.0016325198802455679),
#  (20, 0.0021733138446922502),
#  (30, 0.017826436180217443),
#  (32, 0.014771120098648258),
#  (33, 0.0006783949354975426),
#  (69, 0.0010812364705720333),
#  (123, 0.0),
#  (127, 0.004464606991712861),
#  (119, 0.0013346725661991315),
#  (100, 0.010523200257883284),
#  (85, 0.0),
#  (84, 0.0019489991131074985),
#  (71, 0.0),
#  (72, 0.00841657551221404),
#  (18, 0.007897432063771826)]

# %%
plt.figure(figsize=(10, 6))
plt.step(range(1, max_features + 1), mean_accuracies, where='post', label='Mean Accuracy')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean Accuracy')
plt.title('Cumulative Mean Accuracy Across Folds')
plt.legend()
plt.grid(True)
plt.savefig("step_plot_mi_scores_randomforest.pdf",bbox_inches='tight')

plt.show()

# %%
df = pd.DataFrame(average_feature_scores)
df.rename(columns = {0:'features',1:'mi_scores'}, inplace=True)
df
# Out:
#      features  mi_scores
# 0          21   0.407326
# 1         116   0.385907
# 2         120   0.386536
# 3         118   0.362718
# 4         112   0.359318
# ..        ...        ...
# 125        85   0.000000
# 126        84   0.001949
# 127        71   0.000000
# 128        72   0.008417
# 129        18   0.007897
#
# [130 rows x 2 columns]

# %%
df.to_csv('feature_with_mi_scores_randomforest.csv')

# %%
plt.figure(figsize=(10, 6))
plt.step(range(1, max_features + 1), mean_accuracies, where='post', label='Mean Accuracy')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean Accuracy')
plt.title('Cumulative Mean Accuracy Across Folds')
plt.legend()
plt.grid(True)
plt.savefig("step_plot_mi_scores_randomforest.pdf",bbox_inches='tight')

plt.show()
